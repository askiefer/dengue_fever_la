# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('../data/dengue_features_entire.csv')

# %% [markdown]
# Delete the rows with NaNs

# %%
df = df.dropna()

# %% [markdown]
# Separate the data for each city

# %%
sj = df[df['city'] == "sj"]

# %%
iq = df[df['city'] == "iq"]

# %%
len(sj), len(iq)
# Out:
# (727, 472)

# %%
sj.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k     ...       \
# 0  0.177617                 12.42             297.572857     ...
# 1  0.155486                 22.82             298.211429     ...
# 2  0.170843                 34.54             298.781429     ...
# 3  0.235886                 15.36             298.987143     ...
# 4  0.247340                  7.52             299.518571     ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# ...

# %%
plt.scatter(sj['year'], sj['total_cases'])
plt.xlabel('year')
plt.ylabel('total cases')
plt.suptitle('Year vs. Total Cases')

# %%
plt.scatter(sj['weekofyear'], sj['total_cases'])
plt.xlabel('week of year')
plt.ylabel('total cases')
plt.suptitle('week of year vs. Total Cases')

# %%
# removed reanalysis_sat_precip_amt_mm as column is
# identical to precipitation_amt_mm
columns = ['year',
 'weekofyear',
 'ndvi_ne',
 'ndvi_nw',
 'ndvi_se',
 'ndvi_sw',
 'precipitation_amt_mm',
 'reanalysis_air_temp_k',
 'reanalysis_avg_temp_k',
 'reanalysis_dew_point_temp_k',
 'reanalysis_max_air_temp_k',
 'reanalysis_min_air_temp_k',
 'reanalysis_precip_amt_kg_per_m2',
 'reanalysis_relative_humidity_percent',
 'reanalysis_specific_humidity_g_per_kg',
 'reanalysis_tdtr_k',
 'station_avg_temp_c',
 'station_diur_temp_rng_c',
 'station_max_temp_c',
 'station_min_temp_c',
 'station_precip_mm']
for column in columns:
    plt.scatter(sj[column], sj['total_cases'])
    plt.xlabel(column)
    plt.ylabel('total cases')
    title = '{}'.format(column).replace("_", " ").title()
    plt.suptitle(title + ' vs. Total Cases')
    plt.show()

# %% [markdown]
# ## Variable correlations with total cases:
# - precipitation_amt_mm - weak negative
# - reanalysis_air_temp_k - weak positive
# - reanalysis_avg_temp_k - weak positive
# - reanalysis_dew_point_k - weak positive
# - reanalysis_max_air_temp_k - weak positive
# - reanalysis_min_air_temp_k - weak positive
# - reanalysis_relative_humidity_percent - weak positive
# - reanalysis_specific_humidity_g_per_kg - weak positive
# - station_avg_temp - positive

# %%
plt.scatter(sj['ndvi_ne'], sj['ndvi_se'], color=['blue', 'green'])
plt.xlabel('ndvi_ne')
plt.ylabel('ndvi_se')

# %%
plt.scatter(sj['reanalysis_air_temp_k'], sj['reanalysis_avg_temp_k'], color=['blue', 'green'])
plt.xlabel('reanalysis_air_temp_k')
plt.ylabel('reanalysis_avg_temp_k')
plt.suptitle('Reanalysis Air Temp (k) vs. Reanalysis Avg Temp (k)')

# %%
plt.scatter(sj['reanalysis_air_temp_k'], sj['station_avg_temp_c'], color=['blue', 'green'])
plt.xlabel('reanalysis_air_temp_k')
plt.ylabel('station_avg_temp_c')
plt.suptitle('Reanalysis Air Temp (k) vs. Station Avg Temp (c)')

# %%
plt.scatter(sj['reanalysis_max_air_temp_k'], sj['station_max_temp_c'], color=['blue', 'green'])
plt.xlabel('reanalysis_max_air_temp_k')
plt.ylabel('station_max_temp_c')
plt.suptitle('Reanalysis Max Air Temp (k) vs. Station Max Temp (c)')

# %%
plt.scatter(sj['reanalysis_min_air_temp_k'], sj['station_min_temp_c'], color=['blue', 'green'])
plt.xlabel('reanalysis_min_air_temp_k')
plt.ylabel('station_min_temp_c')
plt.suptitle('Reanalysis Min Air Temp (k) vs. Station Min Temp (c)')

# %%
plt.scatter(sj['reanalysis_relative_humidity_percent'], sj['reanalysis_specific_humidity_g_per_kg'], color=['blue', 'green'])
plt.xlabel('reanalysis_relative_humidity_percent')
plt.ylabel('reanalysis_specific_humidity_g_per_kg')
plt.suptitle('Reanalysis Relative Humidity (%) vs. Reanalysis Specific Humidity (g per kg)')
